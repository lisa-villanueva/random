# %%
import pandas as pd

# Create a DataFrame to represent companies and their associated AI models, including new columns like Licensing and Release Year
data = {
    "Company": [
        "OpenAI", "Anthropic", "Meta", "Google", "Google DeepMind",
        "Microsoft", "xAI", "Hugging Face", "NVIDIA", "Cohere",
        "Stability AI", "AI21 Labs", "EleutherAI", "Mistral", "IBM"
    ],
    "AI Model(s)": [
        "GPT-4, DALL-E, CLIP, Codex", "Claude", "LLaMA, Galactica",
        "BERT, PaLM, Gemini, T5", "AlphaGo, AlphaFold, Gopher, MuZero",
        "Copilot (GPT-4)", "Grok", "BLOOM, DistilBERT, RoBERTa", "Megatron, NeMo",
        "Cohere Command R", "Stable Diffusion", "Jurassic-1", "GPT-Neo, GPT-J",
        "Mistral 7B", "Watson Assistant, Watson NLP"
    ],
    "Type of AI": [
        "Language Models, Generative AI, Image Generation, Multimodal AI",
        "Conversational AI", "Language Model, Scientific Research Model",
        "Language Models, Conversational AI, Multimodal AI",
        "Specialized AI (Game Playing, Protein Folding, Reinforcement Learning)",
        "Productivity AI", "Conversational AI", "Language Models, Open-source Models",
        "Language Models, Conversational AI", "Language Model",
        "Generative AI (Image Generation)", "Language Model", "Language Models",
        "Language Model", "Conversational AI, Language Models"
    ],
    "Model Type": [
        "Conversational AI, Image Generation, Multimodal AI", "Chatbot",
        "NLP Model, Scientific Research Model", "Language Models, Conversational AI",
        "Game Playing, Protein Folding, Reinforcement Learning",
        "Productivity AI", "Conversational AI", "Open-source, Language Models",
        "Language Models, Conversational AI", "Language Model",
        "Image Generation", "Language Model", "Language Models", "Language Model",
        "Conversational AI, Language Models"
    ],
    "Licensing": [
        "Proprietary", "Proprietary", "Open-source", "Proprietary", "Proprietary",
        "Proprietary", "Proprietary", "Open-source", "Proprietary", "Proprietary",
        "Open-source", "Proprietary", "Open-source", "Open-source", "Proprietary"
    ],
    "Release Year": [
        2023, 2023, 2023, 2023, 2016,
        2023, 2023, 2022, 2023, 2023,
        2022, 2021, 2021, 2023, 2011
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

df

# # Print the DataFrame (optional)
# print(df)
# df.to_string(index=False)
# Out:
#             Company                         AI Model(s)  \
# 0            OpenAI          GPT-4, DALL-E, CLIP, Codex
# 1         Anthropic                              Claude
# 2              Meta                    LLaMA, Galactica
# 3            Google              BERT, PaLM, Gemini, T5
# 4   Google DeepMind  AlphaGo, AlphaFold, Gopher, MuZero
# 5         Microsoft                     Copilot (GPT-4)
# 6               xAI                                Grok
# 7      Hugging Face          BLOOM, DistilBERT, RoBERTa
# 8            NVIDIA                      Megatron, NeMo
# 9            Cohere                    Cohere Command R
# 10     Stability AI                    Stable Diffusion
# 11        AI21 Labs                          Jurassic-1
# 12       EleutherAI                      GPT-Neo, GPT-J
# 13          Mistral                          Mistral 7B
# 14              IBM        Watson Assistant, Watson NLP
#
#                                            Type of AI  \
# ...
